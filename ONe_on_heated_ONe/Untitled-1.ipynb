# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# ファイルパスを指定
file_path = "LOGS/history.data"
# ファイルを読み込んでDをEに置き換える
with open(file_path, 'r') as f:
    lines = f.readlines()[6:-1]  # 最初の24行と最後の9行をスキップ
# 各行を分割し、数値として読み込む
data = np.array([list(map(float, line.split())) for line in lines])

time = data[:, 2]-np.min(data[:,2])
R = 10 ** data[:, 44]
cntr_rho = 10 ** data[:, 64]
cntr_temp = 10 ** data[:, 65]
L_nuc = 10 ** data[:, 23]
L = 10 ** data[:, 43] * 3.8e33
model = data[:,0]

plt.plot(time,cntr_temp ,label = "temp")
plt.scatter(time[model == 185],cntr_temp[model == 185] ,label = "model1")
plt.scatter(time[model == 186],cntr_temp[model == 186] ,label = "model2")
plt.scatter(time[model == 188],cntr_temp[model == 188] ,label = "model3")
plt.scatter(time[model == 193],cntr_temp[model == 193] ,label = "model4")
plt.scatter(time[model == 325],cntr_temp[model == 325] ,label = "model5")
plt.scatter(time[model == 345],cntr_temp[model == 345] ,label = "model6")
plt.scatter(time[model == 355],cntr_temp[model == 355] ,label = "model7")
plt.scatter(time[model == 530],cntr_temp[model == 530] ,label = "model8")
plt.scatter(time[model == 560],cntr_temp[model == 560] ,label = "model9")
plt.legend()
#plt.xlim(-1,20)
#plt.ylim(2.3e8,2.7e8)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# ファイルパスを指定
file_path = "LOGS/history.data"
# ファイルを読み込んでDをEに置き換える
with open(file_path, 'r') as f:
    lines = f.readlines()[6:-1]  # 最初の24行と最後の9行をスキップ
# 各行を分割し、数値として読み込む
data = np.array([list(map(float, line.split())) for line in lines])

time = data[:, 2]-np.min(data[:,2])
R = 10 ** data[:, 44]
cntr_rho = 10 ** data[:, 64]
cntr_temp = 10 ** data[:, 65]
L_nuc = 10 ** data[:, 23]
L = 10 ** data[:, 43] * 3.8e33
model = data[:,0]

plt.plot(time,R ,label = "rad")
plt.scatter(time[model == 185],R[model == 185] ,label = "model1")
plt.scatter(time[model == 186],R[model == 186] ,label = "model2")
plt.scatter(time[model == 188],R[model == 188] ,label = "model3")
plt.scatter(time[model == 193],R[model == 193] ,label = "model4")
plt.scatter(time[model == 325],R[model == 325] ,label = "model5")
plt.scatter(time[model == 345],R[model == 345] ,label = "model6")
plt.scatter(time[model == 355],R[model == 355] ,label = "model7")
plt.scatter(time[model == 530],R[model == 530] ,label = "model8")
plt.scatter(time[model == 560],R[model == 560] ,label = "model9")

plt.legend()
#plt.xlim(-1,20)
#plt.ylim(2.3e8,2.7e8)

# %%
# 各行を分割し、数値として読み込む
data = np.array([list(map(float, line.split())) for line in lines])

# %%
time = data[:, 2]-np.min(data[:,2])

# %%
plt.plot(time,data[:, 43],label = "Lum")
plt.xscale("log")
plt.legend()
