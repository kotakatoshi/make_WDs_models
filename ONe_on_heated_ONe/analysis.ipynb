# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# ファイルパスを指定
file_path = "LOGS/profile17.data"

# ファイルを開いて行を読み込む
with open(file_path, 'r') as f:
    lines = f.readlines()

# 5行目（インデックス4）を列名として取得
column_names = lines[5].strip().split()

# 6行目以降のデータを取得
data_lines = lines[6:]  # 最初の5行をスキップ

# DをEに置き換え
data_lines = [line.replace('D', 'E') for line in data_lines]

# 各行を分割し、数値として読み込む
data = np.array([list(map(float, line.split())) for line in data_lines])

# DataFrameを作成
df = pd.DataFrame(data, columns=column_names)

# 結果を確認
print(df)

# R列のデータを取り出す例
print(df["zone"])
#zone = df["zone"].to_numpy()
#zone
# Out:
#       zone          mass      logR      logT    logRho       logP  \
# 0      1.0  1.115480e+00 -2.058550  5.845704 -4.518158   9.191159
# 1      2.0  1.115480e+00 -2.058682  5.945642 -4.254920   9.579532
# 2      3.0  1.115480e+00 -2.058754  5.992243 -4.094903   9.781334
# 3      4.0  1.115480e+00 -2.058804  6.025156 -3.989194   9.918633
# 4      5.0  1.115480e+00 -2.058843  6.050106 -3.911289  10.020980
# ..     ...           ...       ...       ...       ...        ...
# 989  990.0  1.719640e-06 -4.492782  8.198741  7.862916  25.136338
# 990  991.0  8.598201e-07 -4.593132  8.198744  7.862943  25.136375
# 991  992.0  4.299101e-07 -4.693480  8.198746  7.862960  25.136399
# 992  993.0  2.149550e-07 -4.793826  8.198747  7.862971  25.136413
# 993  994.0  1.074775e-07 -4.894170  8.198748  7.862980  25.136426
#
#      x_mass_fraction_H  y_mass_fraction_He  z_mass_fraction_metals    entropy  \
# 0         0.000000e+00        0.000000e+00                     1.0  10.818046
# 1         0.000000e+00        0.000000e+00                     1.0  11.101950
# 2         0.000000e+00        0.000000e+00                     1.0  11.001809
# 3         0.000000e+00        0.000000e+00                     1.0  10.938946
# 4         0.000000e+00        0.000000e+00                     1.0  10.891242
# ..                 ...                 ...                     ...        ...
# 989       1.000000e-99        3.174099e-49                     1.0   0.714004
# 990       1.000000e-99        3.176535e-49                     1.0   0.714000
# 991       1.000000e-99        3.178062e-49                     1.0   0.713997
# 992       1.000000e-99        3.179030e-49                     1.0   0.713996
# 993       1.000000e-99        3.179843e-49                     1.0   0.713994
#
#      ...           n15       o16           o17           o18           f19  \
# 0    ...  0.000000e+00  0.500000  0.000000e+00  0.000000e+00  0.000000e+00
# 1    ...  0.000000e+00  0.500000  0.000000e+00  0.000000e+00  0.000000e+00
# 2    ...  0.000000e+00  0.500000  0.000000e+00  0.000000e+00  0.000000e+00
# 3    ...  0.000000e+00  0.500000  0.000000e+00  0.000000e+00  0.000000e+00
# 4    ...  0.000000e+00  0.500000  0.000000e+00  0.000000e+00  0.000000e+00
# ..   ...           ...       ...           ...           ...           ...
# 989  ...  1.000000e-99  0.499999  4.086248e-76  1.000002e-99  1.000002e-99
# 990  ...  1.000000e-99  0.499999  2.978444e-78  1.000002e-99  1.000002e-99
# 991  ...  1.000000e-99  0.499999  1.766990e-79  1.000002e-99  1.000002e-99
# 992  ...  1.000000e-99  0.499999  1.712193e-79  1.000002e-99  1.000002e-99
# 993  ...  1.000000e-99  0.499999  2.999975e-80  1.000002e-99  1.000002e-99
#
#          ne20          ne22          mg24          si28      logL
# 0    0.000000  0.000000e+00  0.000000e+00  0.000000e+00  3.818735
# 1    0.000000  0.000000e+00  0.000000e+00  0.000000e+00  3.818843
# 2    0.000000  0.000000e+00  0.000000e+00  0.000000e+00  3.818856
# 3    0.000000  0.000000e+00  0.000000e+00  0.000000e+00  3.818775
# 4    0.000000  0.000000e+00  0.000000e+00  0.000000e+00  3.818718
# ..        ...           ...           ...           ...       ...
# 989  0.500001  1.000002e-99  8.741390e-49  1.832747e-47 -5.220586
# 990  0.500001  1.000002e-99  7.017926e-49  1.834222e-47 -5.520838
# 991  0.500001  1.000002e-99  7.019123e-49  1.835152e-47 -5.819843
# 992  0.500001  1.000002e-99  7.020368e-49  1.835737e-47 -6.116163
# 993  0.500001  1.000002e-99  7.066819e-49  1.836230e-47 -6.406772
#
# [994 rows x 34 columns]
# 0        1.0
# 1        2.0
# 2        3.0
# 3        4.0
# 4        5.0
#        ...
# 989    990.0
# 990    991.0
# 991    992.0
# 992    993.0
# 993    994.0
# Name: zone, Length: 994, dtype: float64

# %%
plt.plot(10**df["logR"].to_numpy()* 7e10,10**df["logT"].to_numpy(),label = "temp")
#plt.yscale("log")
plt.legend()

# %%
plt.plot(10**df["logR"].to_numpy()* 7e10,10**df["logP"].to_numpy(),label = "Press")
#plt.plot(R,prad,label = "Prad")
plt.plot(10**df["logR"].to_numpy()* 7e10,df["pgas"].to_numpy(),label = "Pgas")
#plt.plot(R,P - pgas- prad,label = "dP")
plt.yscale("log")
plt.legend()

# %%
plt.plot(10**df["logR"].to_numpy()* 7e10,10**df["logL"].to_numpy()* 3.8e33,label = "luminosity")

#plt.plot(R,P - pgas- prad,label = "dP")
plt.yscale("log")
plt.legend()

# %%
#plt.plot(R,c12,label = "c")
plt.plot(10**df["logR"].to_numpy()* 7e10,df["o16"].to_numpy(),label = "o")
plt.plot(10**df["logR"].to_numpy()* 7e10,df["ne20"].to_numpy()+df["ne22"].to_numpy(),label = "ne")
plt.plot(10**df["logR"].to_numpy()* 7e10,df["c12"].to_numpy(),label = "c")
#plt.plot(R,P - pgas- prad,label = "dP")

plt.legend()
